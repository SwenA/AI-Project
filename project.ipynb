# %%
import numpy as np
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
import warnings
from numpy.random import default_rng

random=default_rng(42) 

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
general_data = pd.read_csv('./data/general_data.csv')
general_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
manager_survey_data = pd.read_csv('./data/manager_survey_data.csv')
manager_survey_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         4410 non-null   int64
#  1   JobInvolvement     4410 non-null   int64
#  2   PerformanceRating  4410 non-null   int64
# dtypes: int64(3)
# memory usage: 103.5 KB

# %%
employee_survey_data = pd.read_csv('./data/employee_survey_data.csv')
employee_survey_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   EnvironmentSatisfaction  4385 non-null   float64
#  2   JobSatisfaction          4390 non-null   float64
#  3   WorkLifeBalance          4372 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 137.9 KB

# %%
with zipfile.ZipFile('./data/in_out_time.zip', 'r') as z:
    with z.open('in_time.csv') as i:
        in_time = pd.read_csv(i)
    with z.open('out_time.csv') as o:
        out_time = pd.read_csv(o)

# %%
in_time.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06         NaN
# ...

# %%
in_time.iloc[:, 1:] = in_time.iloc[:, 1:].apply(pd.to_datetime)
in_time.head()
# Out:
#    Unnamed: 0 2015-01-01           2015-01-02           2015-01-05  \
# 0           1        NaT  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2        NaT  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3        NaT  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4        NaT  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5        NaT  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaT  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13 2015-01-14  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06        NaT
# ...

# %%
out_time.iloc[:, 1:] = out_time.iloc[:, 1:].apply(pd.to_datetime)
out_time.head()
# Out:
#    Unnamed: 0 2015-01-01           2015-01-02           2015-01-05  \
# 0           1        NaT  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2        NaT  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3        NaT  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4        NaT  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5        NaT  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                  NaT  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13 2015-01-14  \
# 0  2015-01-09 17:38:29  2015-01-12 16:58:39  2015-01-13 18:02:58        NaT
# ...

# %%
worked_time = out_time.iloc[:,1:] - in_time.iloc[:,1:]

# %%
worked_time.head()
# Out:
#   2015-01-01       2015-01-02       2015-01-05       2015-01-06  \
# 0        NaT  0 days 07:12:30  0 days 07:11:23  0 days 07:24:39
# 1        NaT  0 days 08:06:33  0 days 07:27:17              NaT
# 2        NaT  0 days 06:41:33  0 days 07:15:56  0 days 06:24:19
# 3        NaT  0 days 07:20:18  0 days 07:17:31  0 days 06:56:35
# 4        NaT  0 days 08:03:20  0 days 07:59:17  0 days 07:40:57
#
#         2015-01-07       2015-01-08       2015-01-09       2015-01-12  \
# 0  0 days 07:00:24  0 days 07:17:23  0 days 07:29:04  0 days 07:15:46
# 1  0 days 07:23:49  0 days 07:25:00  0 days 07:09:03  0 days 07:36:41
# 2  0 days 06:45:54  0 days 07:20:42  0 days 06:51:41  0 days 07:25:07
# 3  0 days 06:55:10  0 days 06:51:03  0 days 07:11:35  0 days 06:59:55
# 4  0 days 07:48:22  0 days 07:39:44  0 days 07:43:18  0 days 08:21:54
#
#         2015-01-13 2015-01-14       2015-01-15       2015-01-16  \
# 0  0 days 07:49:52        NaT  0 days 07:20:49  0 days 07:16:03
# ...

# %%
columns_to_delete = ['2015-01-01', '2015-01-14', '2015-01-26', '2015-03-05',
                        '2015-05-01', '2015-07-17', '2015-09-17', '2015-10-02',
                        '2015-11-09', '2015-11-10', '2015-11-11', '2015-12-25']

for col in columns_to_delete:
    if col in worked_time.columns:
        worked_time.drop([col], axis=1, inplace=True)

# %%
worked_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Columns: 249 entries, 2015-01-02 to 2015-12-31
# dtypes: object(249)
# memory usage: 8.4+ MB

# %%
worked_time = worked_time/np.timedelta64(1, 'h')
worked_time['hrs'] = worked_time.mean(axis=1)

# %%
worked_time.head()
# Out:
#    2015-01-02  2015-01-05  2015-01-06  2015-01-07  2015-01-08  2015-01-09  \
# 0    7.208333    7.189722    7.410833    7.006667    7.289722    7.484444
# 1    8.109167    7.454722         NaN    7.396944    7.416667    7.150833
# 2    6.692500    7.265556    6.405278    6.765000    7.345000    6.861389
# 3    7.338333    7.291944    6.943056    6.919444    6.850833    7.193056
# 4    8.055556    7.988056    7.682500    7.806111    7.662222    7.721667
#
#    2015-01-12  2015-01-13  2015-01-15  2015-01-16  2015-01-19  2015-01-20  \
# 0    7.262778    7.831111    7.346944    7.267500         NaN    6.775833
# 1    7.611389    7.278889    7.613056    7.727500    7.577500    7.602778
# 2    7.418611    6.999722    7.438333    7.210278    7.072222    6.920556
# 3    6.998611    7.306389    6.876667    6.907778    6.518611    7.178889
# 4    8.365000    8.257222    8.260000    8.403611         NaN    7.815278
#
# ...

# %%
worked_time.reset_index(inplace=True)
worked_time['index'] += 1

# %%
worked_time.head()
# Out:
#    index  2015-01-02  2015-01-05  2015-01-06  2015-01-07  2015-01-08  \
# 0      1    7.208333    7.189722    7.410833    7.006667    7.289722
# 1      2    8.109167    7.454722         NaN    7.396944    7.416667
# 2      3    6.692500    7.265556    6.405278    6.765000    7.345000
# 3      4    7.338333    7.291944    6.943056    6.919444    6.850833
# 4      5    8.055556    7.988056    7.682500    7.806111    7.662222
#
#    2015-01-09  2015-01-12  2015-01-13  2015-01-15  2015-01-16  2015-01-19  \
# 0    7.484444    7.262778    7.831111    7.346944    7.267500         NaN
# 1    7.150833    7.611389    7.278889    7.613056    7.727500    7.577500
# 2    6.861389    7.418611    6.999722    7.438333    7.210278    7.072222
# 3    7.193056    6.998611    7.306389    6.876667    6.907778    6.518611
# 4    7.721667    8.365000    8.257222    8.260000    8.403611         NaN
#
#    2015-01-20  2015-01-21  2015-01-22  2015-01-23  2015-01-27  2015-01-28  \
# ...

# %%
worked_time.drop(worked_time.columns.difference(['index','hrs']), axis=1, inplace=True)

# %%
worked_time.rename(columns={'index': 'EmployeeID'},inplace=True)

# %%
worked_time.head(6)
# Out:
#    EmployeeID        hrs
# 0           1   7.373651
# 1           2   7.718969
# 2           3   7.013240
# 3           4   7.193678
# 4           5   8.006175
# 5           6  10.796096

# %%
df_1 = pd.merge(employee_survey_data, general_data, how='inner', on='EmployeeID')
all_data = pd.merge(manager_survey_data, df_1, how='inner', on='EmployeeID')
all_data = pd.merge(worked_time, all_data, how='inner', on='EmployeeID')
all_data = all_data.drop(['EmployeeID'], axis=1)

# %%
all_data.head()
# Out:
#         hrs  JobInvolvement  PerformanceRating  EnvironmentSatisfaction  \
# 0  7.373651               3                  3                      3.0
# 1  7.718969               2                  4                      3.0
# 2  7.013240               3                  3                      2.0
# 3  7.193678               2                  3                      4.0
# 4  8.006175               3                  3                      4.0
#
#    JobSatisfaction  WorkLifeBalance  Age Attrition     BusinessTravel  \
# 0              4.0              2.0   51        No      Travel_Rarely
# 1              2.0              4.0   31       Yes  Travel_Frequently
# 2              2.0              1.0   32        No  Travel_Frequently
# 3              4.0              3.0   38        No         Non-Travel
# 4              1.0              3.0   32        No      Travel_Rarely
#
#                Department  DistanceFromHome  Education EducationField  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

label_cat = all_data[["Attrition"]]

cat_encoder = OneHotEncoder(categories=[['No', 'Yes']], drop='if_binary')
label_cat_1hot=cat_encoder.fit_transform(label_cat)
label_cat_1hot
# Out:
# <4410x1 sparse matrix of type '<class 'numpy.float64'>'
# 	with 711 stored elements in Compressed Sparse Row format>

# %%
all_data['Attrition'] = label_cat_1hot.toarray()

# %%
all_data['Attrition']
# Out:
# 0       0.0
# 1       1.0
# 2       0.0
# 3       0.0
# 4       0.0
#        ...
# 4405    0.0
# 4406    0.0
# 4407    0.0
# 4408    0.0
# 4409    0.0
# Name: Attrition, Length: 4410, dtype: float64

# %%
all_data['Education'] = all_data['Education'].replace({ 1 : 'Below College', 2: 'College',3: 'Bachelor',4: 'Master',5 : 'PhD'})
all_data['EnvironmentSatisfaction'] = all_data['EnvironmentSatisfaction'].replace({ 1 : 'Low', 2: 'Medium',3: 'High',4: 'Very High'})
all_data['JobInvolvement'] = all_data['JobInvolvement'].replace({ 1 : 'Low', 2: 'Medium',3: 'High',4: 'Very High'})
all_data['JobSatisfaction'] = all_data['JobSatisfaction'].replace({ 1 : 'Low', 2: 'Medium',3: 'High',4: 'Very High'})
all_data['PerformanceRating'] = all_data['PerformanceRating'].replace({ 1 : 'Low', 2: 'Good',3: 'Excellent',4: 'Outstanding'})
all_data['WorkLifeBalance'] = all_data['WorkLifeBalance'].replace({ 1 : 'Bad', 2: 'Good',3: 'Better',4: 'Best'})

# %%
all_data.head()
# Out:
#         hrs JobInvolvement PerformanceRating EnvironmentSatisfaction  \
# 0  7.373651           High         Excellent                    High
# 1  7.718969         Medium       Outstanding                    High
# 2  7.013240           High         Excellent                  Medium
# 3  7.193678         Medium         Excellent               Very High
# 4  8.006175           High         Excellent               Very High
#
#   JobSatisfaction WorkLifeBalance  Age  Attrition     BusinessTravel  \
# 0       Very High            Good   51        0.0      Travel_Rarely
# 1          Medium            Best   31        1.0  Travel_Frequently
# 2          Medium             Bad   32        0.0  Travel_Frequently
# 3       Very High          Better   38        0.0         Non-Travel
# 4             Low          Better   32        0.0      Travel_Rarely
#
#                Department  DistanceFromHome      Education EducationField  \
# ...

# %%
all_data = all_data.drop(['EmployeeCount', 'Over18'], axis=1)

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(all_data, random_state=42)
X_train = train_set.drop("Attrition", axis=1)
X_test = test_set.drop("Attrition", axis=1)
y_train = train_set["Attrition"].copy()
y_test = test_set["Attrition"].copy()

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer


X_num = X_train.select_dtypes(include=[np.number])
X_cat = X_train.select_dtypes(include=['object', 'string']) 
num_attribs = list(X_num)
cat_attribs = list(X_cat)
        
num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        ('std_scaler', StandardScaler()),
    ])

full_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
        ("cat", OneHotEncoder(sparse_output=True), cat_attribs),
    ],
    remainder='passthrough')

X_prepared = full_pipeline.fit_transform(X_train)

# %%
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate', fontsize=16)
    plt.ylabel('True Positive Rate', fontsize=16)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, roc_auc_score, confusion_matrix
from sklearn.model_selection import cross_val_predict

def cross_validation_predict (model, X, y, cv=3, method=None, label=None):

    if not isinstance(method, str):
        raise ValueError("Le paramètre 'method' doit être une chaîne de caractères (string).")
    
    if not isinstance(label, str):
        raise ValueError("Le paramètre 'label' doit être une chaîne de caractères (string).")
    
    if  method == 'decision_function':
        cvp_scores = cross_val_predict(model, X, y, cv=cv, method='predict')

        print('precision: ', precision_score(y, cvp_scores))
        print('recall: ', recall_score(y, cvp_scores))
        print('f1 score: ', f1_score(y, cvp_scores))
        print('Confusion matrix: \n', confusion_matrix(y, cvp_scores))


        cvp_scores = cross_val_predict(model, X, y, cv=cv, method=method)
        fpr, tpr, thresholds = roc_curve(y,  cvp_scores)

        print('AUC: ',roc_auc_score(y, cvp_scores))

        plt.figure(figsize=(8, 6))
        plt.title(label + ' ROC curve')
        plot_roc_curve(fpr, tpr, label)
        plt.show()
    

    if method == 'predict_proba':
        cvp_scores = cross_val_predict(model, X, y, cv=cv, method='predict')

        print('precision: ', precision_score(y, cvp_scores))
        print('recall: ', recall_score(y, cvp_scores))
        print('f1 score: ', f1_score(y, cvp_scores))
        print('Confusion matrix: \n', confusion_matrix(y, cvp_scores))


        cvp_scores = cross_val_predict(model, X, y, cv=cv, method=method)
        fpr, tpr, thresholds = roc_curve(y,  cvp_scores[:,1])

        print('AUC: ',roc_auc_score(y, cvp_scores[:,1]))
        
        plt.figure(figsize=(8, 6))
        plt.title(label + ' ROC curve')
        plot_roc_curve(fpr, tpr, label)
        plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV


lgt_clf = LogisticRegression(random_state=42)
cross_validation_predict(lgt_clf, X_prepared, y_train, method='decision_function', label='Logistic regression')
# Out:
# precision:  0.634453781512605
# recall:  0.27808471454880296
# f1 score:  0.3866837387964149
# Confusion matrix:
#  [[2677   87]
#  [ 392  151]]
# AUC:  0.8223349137689793

# %%
from sklearn.neural_network import MLPClassifier

mlp_clf = MLPClassifier(max_iter=1000, random_state=42)

param_distribs = {
    'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50)], 
    'activation': ['relu', 'tanh'],  
    'solver': ['sgd', 'adam'],
}

rnd_search_cv = RandomizedSearchCV(mlp_clf, param_distribs, n_iter=30, cv=3, random_state=42, verbose=2)

rnd_search_cv.fit(X_prepared, y_train)

print("Meilleurs paramètres:", rnd_search_cv.best_params_)
print("Meilleur score:", rnd_search_cv.best_score_)

best_mlp_clf = rnd_search_cv.best_estimator_
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] END activation=relu, hidden_layer_sizes=(50,), solver=sgd; total time=   9.3s
# [CV] END activation=relu, hidden_layer_sizes=(50,), solver=sgd; total time=   9.3s
# [CV] END activation=relu, hidden_layer_sizes=(50,), solver=sgd; total time=   8.5s
# [CV] END activation=relu, hidden_layer_sizes=(50,), solver=adam; total time=   4.4s
# [CV] END activation=relu, hidden_layer_sizes=(50,), solver=adam; total time=   4.9s
# [CV] END activation=relu, hidden_layer_sizes=(50,), solver=adam; total time=   4.6s
# [CV] END activation=relu, hidden_layer_sizes=(100,), solver=sgd; total time=  10.9s
# [CV] END activation=relu, hidden_layer_sizes=(100,), solver=sgd; total time=  10.9s
# [CV] END activation=relu, hidden_layer_sizes=(100,), solver=sgd; total time=  10.6s
# [CV] END activation=relu, hidden_layer_sizes=(100,), solver=adam; total time=   3.6s
# ...

# %%
cross_validation_predict(mlp_clf, X_prepared, y_train, cv=8, method='predict_proba', label='MLP Classifier')
# Out:
# precision:  0.9519230769230769
# recall:  0.9116022099447514
# f1 score:  0.9313264346190028
# [[2739   25]
#  [  48  495]]
# AUC:  0.9726621945401679

# %%
import seaborn as sns

all_data_titles = full_pipeline.get_feature_names_out()
all_data_prepared = pd.DataFrame(full_pipeline.fit_transform(all_data), columns=all_data_titles)
corr_matrix = all_data_prepared.corr(numeric_only=True)

corr_matrix_with_attrition = corr_matrix["remainder__Attrition"].sort_values(ascending=True)

corr_with_attrition_df = corr_matrix_with_attrition.to_frame()

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 20))  # Ajustez la taille selon le nombre de caractéristiques

# Generate a custom diverging colormap
cmap = sns.diverging_palette(250, 30, as_cmap=True)

# Draw the heatmap
sns.heatmap(corr_with_attrition_df, annot=True, cmap=cmap, center=0,
            cbar_kws={"shrink": 0.5}, ax=ax)

plt.title('Correlation with Attrition')
plt.show()
